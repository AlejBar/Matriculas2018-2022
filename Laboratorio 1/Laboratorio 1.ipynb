# %% [markdown]
# #[MEN_MATRICULA_EN_EDUCACION_EN_PREESCOLAR, BÁSICA Y MEDIA_2018_2022]
#
# (https://www.datos.gov.co/Educaci-n/MEN_MATRICULA_EN_EDUCACION_EN_PREESCOLAR-B-SICA-Y-/sty3-c395/about_data)
#
# ##*Ficha técnica*
# ---
#
#
# Contiene la matrícula estadística de Educación Preescolar Básica y Media de Colombia del corte 2018 al 2022.
#
#
# ---
#
#
# NOTA: la base 2018 esta con proyecciones ajustadas censo 2005.
#
# ---
#
#
# **Última Actualización**
#
# 20 de abril de 2024
#
# **Datos suministrados por**
#
# Ministerio de Educación Nacional
#
# ---
#
#
#
# **Información de la Entidad**
#
# | Área o dependencia                | Nombre de la Entidad          |
# |-----------------------------------|-------------------------------|
# | Oficina Asesora de Planeación y Finanzas | Ministerio de Educación Nacional |
# | Departamento                      | Bogotá D.C.                   |
# | Municipio                         | Bogotá D.C.                   |
# | Orden                             | Nacional                      |
# | Sector                            | Educación                     |
#
# **Información de Datos**
#
# | Campo                           | Valor                        |
# |---------------------------------|------------------------------|
# | Idioma                          | Español                      |
# | Cobertura Geográfica            | Nacional                     |
# | Frecuencia de Actualización     | Anual                        |
# | Fecha Emisión (aaaa-mm-dd)      | 2019-09-12                   |
#
# **Elementos adjuntos**
#
# - [Metodología OE Matricula EPBM_VF2021.pdf](https://www.datos.gov.co/api/views/sty3-c395/files/d7414698-1948-4b4a-b812-52f3adc9da48?download=true&filename=Metodolog%C3%ADa%20OE%20Matricula%20EPBM_VF2021.pdf)
# - [Ficha metodológica OE Matricula EPBM 2022.pdf](https://www.datos.gov.co/api/views/sty3-c395/files/6c9c6529-4645-407b-a045-99701b82d654?download=true&filename=Ficha%20metodol%C3%B3gica%20OE%20Matricula%20EPBM%202022.pdf)
# - [Documento metodológico OE Matrícula MEPBM 2022.pdf](https://www.datos.gov.co/api/views/sty3-c395/files/d6c42d41-129a-4654-95ed-e5a3d2607804?download=true&filename=Documento%20metodol%C3%B3gico%20OE%20Matr%C3%ADcula%20MEPBM%202022.pdf)
# - [NOTAS_EXPLICATIVAS - Marco ODS final.pdf](https://www.datos.gov.co/api/views/sty3-c395/files/e744b673-be1b-4609-8ed2-b004158bd07f?download=true&filename=NOTAS_EXPLICATIVAS%20-%20Marco%20ODS%20final.pdf)
# - [NOTAS_EXPLICATIVAS - Contexto final.pdf](https://www.datos.gov.co/api/views/sty3-c395/files/875e3a82-e902-4da4-8943-e1750021896c?download=true&filename=NOTAS_EXPLICATIVAS%20-%20Contexto%20final.pdf)
#
#
#
#
# *   *Actualizado:* **20 de abril de 2024**
# *   *Vistas:* **31,8k**
# *   *Descargas:* **7.849**
# *   *Filas:* **12,6M**
# *   *Columnas:* **35**
#
# Cada fila es un
# Agregado de matricula por establecimiento educativo, que contiene las variables del establecimiento (sede, zona, jornada, grado, metodología, carácter y sector CONPES) y de la matricula (edad, género y grupo étnico)

# %%
#Laboratio Semana 1
#Saber_11_2018-1

# !pip install pyodbc pandas altair seaborn  altair_viewer matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.7/334.7 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 844.5/844.5 kB 28.0 MB/s eta 0:00:00
# ...

# %%
#Importar librerias
import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pyodbc
import warnings
import sqlite3

# %%
#Llamar los archvios desde drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Especifica la ruta del archivo CSV en tu Google Drive
ruta_del_archivo = '/content/drive/MyDrive/BootCamp/Saber_11_2018_1.csv'

# %%
try:
    # Consumir una API,
    df_ejercicio1_saber_2018 = pd.read_csv('/content/drive/MyDrive/BootCamp/Saber_11_2018_1.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("csv Correcto")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e1:

    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"La API no se puede consumir.{e1}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except exception as ex1:

    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error fatal:{ex1}")
# Out:
# csv Correcto

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_ejercicio1_saber_2018 = pd.DataFrame(df_ejercicio1_saber_2018)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_ejercicio1_saber_2018.shape

# Imprimir mensaje y valores de salidas del dataframe
print (f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 32348 filas y 40 columnas.

# %%
#  Imprimir el dataframe
df_ejercicio1_saber_2018
# Out:
#        periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 0        20181            CC  SB11201810028234        URBANO             N
# 1        20181            CC  SB11201810028234        URBANO             N
# 2        20181            CC  SB11201810047396        URBANO             N
# 3        20181            TI  SB11201810016997        URBANO             S
# 4        20181            TI  SB11201810016997        URBANO             S
# ...        ...           ...               ...           ...           ...
# 32343    20181            TI  SB11201810004242        URBANO             N
# 32344    20181            TI  SB11201810004242        URBANO             N
# 32345    20181            TI  SB11201810021880        URBANO             N
# 32346    20181            TI  SB11201810004880        URBANO             N
# 32347    20181            TI  SB11201810004880        URBANO             N
#
#       cole_calendario cole_caracter cole_depto_ubi cole_genero  \
# ...

# %%
# Ver las primeras filas del dataframe
df_ejercicio1_saber_2018.head(5)
# Out:
#    periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 0    20181            CC  SB11201810028234        URBANO             N
# 1    20181            CC  SB11201810028234        URBANO             N
# 2    20181            CC  SB11201810047396        URBANO             N
# 3    20181            TI  SB11201810016997        URBANO             S
# 4    20181            TI  SB11201810016997        URBANO             S
#
#   cole_calendario cole_caracter cole_depto_ubi cole_genero cole_tipo_jornada  \
# 0               B     ACADÉMICO          VALLE       MIXTO            MAÑANA
# 1               B     ACADÉMICO          VALLE       MIXTO            MAÑANA
# 2               A           NaN         TOLIMA       MIXTO          SABATINA
# 3               B     ACADÉMICO         BOGOTA       MIXTO          COMPLETA
# 4               B     ACADÉMICO         BOGOTA       MIXTO          COMPLETA
#
#    ... fami_tiene_automovil fami_tiene_pc fami_tiene_internet  \
# ...

# %%
#V Ver las ultimas filas del dataframe
df_ejercicio1_saber_2018.tail(5)
# Out:
#        periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 32343    20181            TI  SB11201810004242        URBANO             N
# 32344    20181            TI  SB11201810004242        URBANO             N
# 32345    20181            TI  SB11201810021880        URBANO             N
# 32346    20181            TI  SB11201810004880        URBANO             N
# 32347    20181            TI  SB11201810004880        URBANO             N
#
#       cole_calendario cole_caracter cole_depto_ubi cole_genero  \
# 32343               B     ACADÉMICO          VALLE       MIXTO
# 32344               B     ACADÉMICO          VALLE       MIXTO
# 32345               A     ACADÉMICO      ANTIOQUIA       MIXTO
# 32346               B     ACADÉMICO          VALLE       MIXTO
# 32347               B     ACADÉMICO          VALLE       MIXTO
#
#       cole_tipo_jornada  ... fami_tiene_automovil fami_tiene_pc  \
# 32343            MAÑANA  ...                   Si            Si
# ...

# %%
# Mostrar aleatoramiente filas del Dataframe
df_ejercicio1_saber_2018.sample(10)
# Out:
#        periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 6677     20181            CC  SB11201810052984        URBANO             N
# 30784    20181            CC  SB11201810012226        URBANO             S
# 9562     20181            TI  SB11201810006849        URBANO             N
# 21183    20181            TI  SB11201810017013         RURAL             S
# 14752    20181            TI  SB11201810024780        URBANO             N
# 2130     20181            TI  SB11201810038587        URBANO             N
# 23162    20181            TI  SB11201810007977        URBANO             N
# 14715    20181            TI  SB11201810029352         RURAL             S
# 15950    20181            TI  SB11201810006958        URBANO             S
# 13758    20181            TI  SB11201810021213        URBANO             N
#
#       cole_calendario cole_caracter cole_depto_ubi cole_genero  \
# 6677                A     ACADÉMICO         BOGOTA       MIXTO
# ...

# %%
# Saber el nombre de las columnas del dataframe
df_ejercicio1_saber_2018.columns
# Out:
# Index(['periodo', 'estu_tipo_doc', 'estu_id', 'cole_area_ubi', 'cole_bilingue',
#        'cole_calendario', 'cole_caracter', 'cole_depto_ubi', 'cole_genero',
#        'cole_tipo_jornada', 'cole_mcpio_ubi', 'cole_naturaleza',
#        'cole_nom_establecimiento', 'cole_nom_sede', 'cole_sede_principal',
#        'estu_depto_presentacion', 'estu_depto_reside',
#        'estu_estado_investigacion', 'estu_fecha_nacimiento', 'estu_genero',
#        'estu_mcpio_presentacion', 'estu_mcpio_reside', 'estu_nacionalidad',
#        'estu_pais_reside', 'estu_privado_libertad', 'fami_cuartos',
#        'fami_edu_madre', 'fami_edu_padre', 'fami_estrato',
#        'fami_personas_hogar', 'fami_tiene_automovil', 'fami_tiene_pc',
#        'fami_tiene_internet', 'desempeno_ingles', 'resul_ingles',
#        'resul_matematicas', 'resul_sociales_naturales',
#        'resul_ciencias_naturales', 'resul_lectura_critica', 'resul_global'],
#       dtype='object')

# %%
# Ver información de las columnas del dataframe
df_ejercicio1_saber_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32348 entries, 0 to 32347
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   periodo                    32348 non-null  int64
#  1   estu_tipo_doc              32348 non-null  object
#  2   estu_id                    32348 non-null  object
#  3   cole_area_ubi              32348 non-null  object
#  4   cole_bilingue              27513 non-null  object
#  5   cole_calendario            32348 non-null  object
#  6   cole_caracter              31074 non-null  object
#  7   cole_depto_ubi             32348 non-null  object
#  8   cole_genero                32348 non-null  object
#  9   cole_tipo_jornada          32348 non-null  object
#  10  cole_mcpio_ubi             32348 non-null  object
#  11  cole_naturaleza            32348 non-null  object
#  12  cole_nom_establecimiento   32348 non-null  object
# ...

# %%
# Ver cuantos datos faltan dependiedo de la columna donde se encuentre

df_ejercicio1_saber_2018 = df_ejercicio1_saber_2018.replace(r'^\s*$', np.nan, regex=True)
percent_missing = df_ejercicio1_saber_2018.isnull().sum() * 100 / len(df_ejercicio1_saber_2018)
missing_value_df = pd.DataFrame({'Columnas': df_ejercicio1_saber_2018.columns,
                                 'Porcentajes_vacios': percent_missing})
missing_value_df.sort_values(by="Porcentajes_vacios", ascending= False).reset_index(drop=True)
# Out:
#                      Columnas  Porcentajes_vacios
# 0               cole_bilingue           14.946828
# 1                fami_estrato            5.688141
# 2         fami_tiene_internet            5.434648
# 3              fami_edu_madre            5.428465
# 4              fami_edu_padre            5.422283
# 5               cole_caracter            3.938420
# 6         fami_personas_hogar            3.079016
# 7        fami_tiene_automovil            2.704959
# 8                fami_cuartos            2.531841
# 9               fami_tiene_pc            2.442191
# 10          estu_depto_reside            0.049462
# 11          estu_mcpio_reside            0.049462
# 12          estu_nacionalidad            0.000000
# 13           desempeno_ingles            0.000000
# 14               resul_ingles            0.000000
# 15          resul_matematicas            0.000000
# 16   resul_sociales_naturales            0.000000
# 17   resul_ciencias_naturales            0.000000
# ...

# %%
from matplotlib import pyplot as plt
_df_0['Porcentajes_vacios'].plot(kind='hist', bins=20, title='Porcentajes_vacios')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Parte 2 Laboratio

# %%
# Especifica la ruta del archivo CSV en tu Google Drive
ruta_del_archivo = '/content/drive/MyDrive/BootCamp/Saber_11_2019-2.csv'

# %%
try:
    # Consumir una API,
    df_ejercicio2_saber_2019 = pd.read_csv('/content/drive/MyDrive/BootCamp/Saber_11_2019-2.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("csv Correcto")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e2:

    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"La API no se puede consumir.{e2}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except exception as ex2:

    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error fatal:{ex2}")
# Out:
# csv Correcto

# %%
#Dataframe
df_ejercicio2_saber_2019 = pd.DataFrame(df_ejercicio2_saber_2019)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_ejercicio2_saber_2019.shape

# Imprimir mensaje y valores de salidas del dataframe
print (f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 15528 filas y 40 columnas.

# %%
#  Ver dataframe
df_ejercicio2_saber_2019
# Out:
#        periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 0        20211            TI  SB11202110001547         RURAL             S
# 1        20211            CR  SB11202110021004        URBANO           NaN
# 2        20211            TI  SB11202110002427        URBANO             S
# 3        20211            TI  SB11202110002880        URBANO             N
# 4        20211            TI  SB11202110022054        URBANO             S
# ...        ...           ...               ...           ...           ...
# 15523    20211            TI  SB11202110007181        URBANO             N
# 15524    20211            CC  SB11202110065415        URBANO             N
# 15525    20211            TI  SB11202110064360        URBANO             N
# 15526    20211            CC  SB11202110002939        URBANO             N
# 15527    20211            TI  SB11202110009581        URBANO             N
#
# ...

# %%
# Saber el nombre de las columnas del dataframe
df_ejercicio2_saber_2019.columns
# Out:
# Index(['periodo', 'estu_tipo_doc', 'estu_id', 'cole_area_ubi', 'cole_bilingue',
#        'cole_calendario', 'cole_caracter', 'cole_depto_ubi', 'cole_genero',
#        'cole_tipo_jornada', 'cole_mcpio_ubi', 'cole_naturaleza',
#        'cole_nom_establecimiento', 'cole_nom_sede', 'cole_sede_principal',
#        'estu_depto_presentacion', 'estu_depto_reside',
#        'estu_estado_investigacion', 'estu_fecha_nacimiento', 'estu_genero',
#        'estu_mcpio_presentacion', 'estu_mcpio_reside', 'estu_nacionalidad',
#        'estu_pais_reside', 'estu_privado_libertad', 'fami_cuartos',
#        'fami_edu_madre', 'fami_edu_padre', 'fami_estrato',
#        'fami_personas_hogar', 'fami_tiene_automovil', 'fami_tiene_pc',
#        'fami_tiene_internet', 'desempeno_ingles', 'resul_ingles',
#        'resul_matematicas', 'resul_sociales_naturales',
#        'resul_ciencias_naturales', 'resul_lectura_critica', 'resul_global'],
#       dtype='object')

# %%
# Ver información de las columnas del dataframe
df_ejercicio2_saber_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15528 entries, 0 to 15527
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   periodo                    15528 non-null  int64
#  1   estu_tipo_doc              15528 non-null  object
#  2   estu_id                    15528 non-null  object
#  3   cole_area_ubi              15528 non-null  object
#  4   cole_bilingue              12975 non-null  object
#  5   cole_calendario            15528 non-null  object
#  6   cole_caracter              14789 non-null  object
#  7   cole_depto_ubi             15528 non-null  object
#  8   cole_genero                15528 non-null  object
#  9   cole_tipo_jornada          15528 non-null  object
#  10  cole_mcpio_ubi             15528 non-null  object
#  11  cole_naturaleza            15528 non-null  object
#  12  cole_nom_establecimiento   15528 non-null  object
# ...

# %%
# Ver cuantos datos faltan dependiedo de la columna donde se encuentre

df_ejercicio2_saber_2019 = df_ejercicio2_saber_2019.replace(r'^\s*$', np.nan, regex=True)
percent_missing = df_ejercicio2_saber_2019.isnull().sum() * 100 / len(df_ejercicio2_saber_2019)
missing_value_df = pd.DataFrame({'Columnas': df_ejercicio2_saber_2019.columns,
                                 'Porcentajes_vacios': percent_missing})
missing_value_df.sort_values(by="Porcentajes_vacios", ascending= False).reset_index(drop=True)
# Out:
#                      Columnas  Porcentajes_vacios
# 0               cole_bilingue           16.441267
# 1                fami_estrato            4.868624
# 2               cole_caracter            4.759145
# 3              fami_edu_madre            4.482226
# 4              fami_edu_padre            4.404946
# 5         fami_tiene_internet            4.379186
# 6                fami_cuartos            3.561309
# 7        fami_tiene_automovil            3.541989
# 8         fami_personas_hogar            3.458269
# 9               fami_tiene_pc            3.387429
# 10               resul_ingles            0.302679
# 11           desempeno_ingles            0.302679
# 12          estu_depto_reside            0.051520
# 13          estu_mcpio_reside            0.051520
# 14                estu_genero            0.032200
# 15           estu_pais_reside            0.000000
# 16          resul_matematicas            0.000000
# 17   resul_sociales_naturales            0.000000
# ...

# %%
# !pip install requests

# %%
import requests

# %%
try:
    # Consumir una API,
    df_ejercicio3_2021 = pd.read_csv('https://raw.githubusercontent.com/wespitia9/AVDV2-47/main/Saber_11_2021_1.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("La API es consumida correcta")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileNotFoundError as e3:

    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"La API no se puede consumir.{e3}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as ex3:

    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error fatal:{ex3}")
# Out:
# La API es consumida correcta

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_ejercicio3_2021 = pd.DataFrame(df_ejercicio3_2021)

# %%
# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_ejercicio3_2021.shape

# Imprimir mensaje y valores de salidas del dataframe
print (f'El DataFrame, tiene {num_rows} filas y {num_cols} columnas.')
# Out:
# El DataFrame, tiene 15528 filas y 40 columnas.

# %%
# Ver datos
df_ejercicio3_2021
# Out:
#        periodo estu_tipo_doc           estu_id cole_area_ubi cole_bilingue  \
# 0        20211            TI  SB11202110001547         RURAL             S
# 1        20211            CR  SB11202110021004        URBANO           NaN
# 2        20211            TI  SB11202110002427        URBANO             S
# 3        20211            TI  SB11202110002880        URBANO             N
# 4        20211            TI  SB11202110022054        URBANO             S
# ...        ...           ...               ...           ...           ...
# 15523    20211            TI  SB11202110007181        URBANO             N
# 15524    20211            CC  SB11202110065415        URBANO             N
# 15525    20211            TI  SB11202110064360        URBANO             N
# 15526    20211            CC  SB11202110002939        URBANO             N
# 15527    20211            TI  SB11202110009581        URBANO             N
#
# ...

# %%
# Saber el nombre de las columnas del dataframe
df_ejercicio3_2021.columns
# Out:
# Index(['periodo', 'estu_tipo_doc', 'estu_id', 'cole_area_ubi', 'cole_bilingue',
#        'cole_calendario', 'cole_caracter', 'cole_depto_ubi', 'cole_genero',
#        'cole_tipo_jornada', 'cole_mcpio_ubi', 'cole_naturaleza',
#        'cole_nom_establecimiento', 'cole_nom_sede', 'cole_sede_principal',
#        'estu_depto_presentacion', 'estu_depto_reside',
#        'estu_estado_investigacion', 'estu_fecha_nacimiento', 'estu_genero',
#        'estu_mcpio_presentacion', 'estu_mcpio_reside', 'estu_nacionalidad',
#        'estu_pais_reside', 'estu_privado_libertad', 'fami_cuartos',
#        'fami_edu_madre', 'fami_edu_padre', 'fami_estrato',
#        'fami_personas_hogar', 'fami_tiene_automovil', 'fami_tiene_pc',
#        'fami_tiene_internet', 'desempeno_ingles', 'resul_ingles',
#        'resul_matematicas', 'resul_sociales_naturales',
#        'resul_ciencias_naturales', 'resul_lectura_critica', 'resul_global'],
#       dtype='object')

# %%
# Ver información de las columnas del dataframe
df_ejercicio3_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15528 entries, 0 to 15527
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   periodo                    15528 non-null  int64
#  1   estu_tipo_doc              15528 non-null  object
#  2   estu_id                    15528 non-null  object
#  3   cole_area_ubi              15528 non-null  object
#  4   cole_bilingue              12975 non-null  object
#  5   cole_calendario            15528 non-null  object
#  6   cole_caracter              14789 non-null  object
#  7   cole_depto_ubi             15528 non-null  object
#  8   cole_genero                15528 non-null  object
#  9   cole_tipo_jornada          15528 non-null  object
#  10  cole_mcpio_ubi             15528 non-null  object
#  11  cole_naturaleza            15528 non-null  object
#  12  cole_nom_establecimiento   15528 non-null  object
# ...

# %%
# Ver cuantos datos faltan dependiedo de la columna donde se encuentre

df_ejercicio3_2021 = df_ejercicio3_2021.replace(r'^\s*$', np.nan, regex=True)
percent_missing = df_ejercicio3_2021.isnull().sum() * 100 / len(df_ejercicio3_2021)
missing_value_df = pd.DataFrame({'Columnas': df_ejercicio3_2021.columns,
                                 'Porcentajes_vacios': percent_missing})
missing_value_df.sort_values(by="Porcentajes_vacios", ascending= False).reset_index(drop=True)
# Out:
#                      Columnas  Porcentajes_vacios
# 0               cole_bilingue           16.441267
# 1                fami_estrato            4.868624
# 2               cole_caracter            4.759145
# 3              fami_edu_madre            4.482226
# 4              fami_edu_padre            4.404946
# 5         fami_tiene_internet            4.379186
# 6                fami_cuartos            3.561309
# 7        fami_tiene_automovil            3.541989
# 8         fami_personas_hogar            3.458269
# 9               fami_tiene_pc            3.387429
# 10               resul_ingles            0.302679
# 11           desempeno_ingles            0.302679
# 12          estu_depto_reside            0.051520
# 13          estu_mcpio_reside            0.051520
# 14                estu_genero            0.032200
# 15           estu_pais_reside            0.000000
# 16          resul_matematicas            0.000000
# 17   resul_sociales_naturales            0.000000
# ...
